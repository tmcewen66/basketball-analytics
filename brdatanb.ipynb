# %%
import sqlite3
import time
import pandas as pd

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM basic_stats'
basic_stats_df = pd.read_sql_query(query, conn)

conn.close()

pd.set_option('display.max_columns', None)
basic_stats_df.head()
# Out:
#         slug  season_end_year                 name       positions  age  \
# 0  abdulma02             2001   Mahmoud Abdul-Rauf     POINT GUARD   31
# 1  abdulta01             2001    Tariq Abdul-Wahad  SHOOTING GUARD   26
# 2  abdursh01             2001  Shareef Abdur-Rahim   SMALL FORWARD   24
# 3  alexaco01             2001       Cory Alexander     POINT GUARD   27
# 4  alexaco02             2001   Courtney Alexander     POINT GUARD   23
#
#                                   team  games_played  games_started  \
# 0                  VANCOUVER GRIZZLIES            41              0
# 1                       DENVER NUGGETS            29             12
# 2                  VANCOUVER GRIZZLIES            81             81
# 3                        ORLANDO MAGIC            26              0
# 4  DALLAS MAVERICKS/WASHINGTON WIZARDS            65             24
#
#    minutes_played  made_field_goals  attempted_field_goals  \
# 0             486               120                    246
# ...

# %%
missing_data = basic_stats_df.isna().any(axis=None)
print(missing_data)
# Out:
# False

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM advanced_stats'
advanced_stats_df = pd.read_sql_query(query, conn)

conn.close()

advanced_stats_df.head()
# Out:
#         slug  season_end_year            name      positions  age  \
# 0  finlemi01             2001  Michael Finley  SMALL FORWARD   27
# 1  walkean02             2001  Antoine Walker  POWER FORWARD   24
# 2  jamisan01             2001  Antawn Jamison  SMALL FORWARD   24
# 3  masonan01             2001   Anthony Mason  POWER FORWARD   34
# 4  paytoga01             2001     Gary Payton    POINT GUARD   32
#
#                     team  games_played  minutes_played  \
# 0       DALLAS MAVERICKS            82            3443
# 1         BOSTON CELTICS            81            3396
# 2  GOLDEN STATE WARRIORS            82            3394
# 3             MIAMI HEAT            80            3254
# 4    SEATTLE SUPERSONICS            79            3244
#
#    player_efficiency_rating  true_shooting_percentage  \
# 0                      18.2                     0.521
# 1                      18.9                     0.505
# 2                      19.0                     0.499
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM derived_stats'
derived_stats_df = pd.read_sql_query(query, conn)

conn.close()

derived_stats_df.head()
# Out:
#         slug  season_end_year                 name       positions  age  \
# 0  abdulma02             2001   Mahmoud Abdul-Rauf     POINT GUARD   31
# 1  abdulta01             2001    Tariq Abdul-Wahad  SHOOTING GUARD   26
# 2  abdursh01             2001  Shareef Abdur-Rahim   SMALL FORWARD   24
# 3  alexaco01             2001       Cory Alexander     POINT GUARD   27
# 4  alexaco02             2001   Courtney Alexander     POINT GUARD   23
#
#                                   team  games_played  games_started  \
# 0                  VANCOUVER GRIZZLIES            41              0
# 1                       DENVER NUGGETS            29             12
# 2                  VANCOUVER GRIZZLIES            81             81
# 3                        ORLANDO MAGIC            26              0
# 4  DALLAS MAVERICKS/WASHINGTON WIZARDS            65             24
#
#    minutes_played  made_field_goals  attempted_field_goals  \
# 0             486               120                    246
# ...

# %%
derived_stats_df = derived_stats_df[derived_stats_df['slug'] == 'abdursh01']
derived_stats_df
# Out:
#            slug  season_end_year                 name      positions  age  \
# 2     abdursh01             2001  Shareef Abdur-Rahim  SMALL FORWARD   24
# 442   abdursh01             2002  Shareef Abdur-Rahim  POWER FORWARD   25
# 882   abdursh01             2003  Shareef Abdur-Rahim  POWER FORWARD   26
# 1309  abdursh01             2004  Shareef Abdur-Rahim  POWER FORWARD   27
# 1751  abdursh01             2005  Shareef Abdur-Rahim  POWER FORWARD   28
# 2215  abdursh01             2006  Shareef Abdur-Rahim  POWER FORWARD   29
# 2673  abdursh01             2007  Shareef Abdur-Rahim         CENTER   30
# 3131  abdursh01             2008  Shareef Abdur-Rahim  POWER FORWARD   31
#
#                                       team  games_played  games_started  \
# 2                      VANCOUVER GRIZZLIES            81             81
# 442                          ATLANTA HAWKS            77             77
# 882                          ATLANTA HAWKS            81             81
# ...

# %%
sar_advanced_stats_df = advanced_stats_df[advanced_stats_df['slug'] == 'abdursh01']
sar_advanced_stats_df
# Out:
#            slug  season_end_year                 name      positions  age  \
# 5     abdursh01             2001  Shareef Abdur-Rahim  SMALL FORWARD   24
# 465   abdursh01             2002  Shareef Abdur-Rahim  POWER FORWARD   25
# 898   abdursh01             2003  Shareef Abdur-Rahim  POWER FORWARD   26
# 1359  abdursh01             2004  Shareef Abdur-Rahim  POWER FORWARD   27
# 1878  abdursh01             2005  Shareef Abdur-Rahim  POWER FORWARD   28
# 2338  abdursh01             2006  Shareef Abdur-Rahim  POWER FORWARD   29
# 2797  abdursh01             2007  Shareef Abdur-Rahim         CENTER   30
# 3556  abdursh01             2008  Shareef Abdur-Rahim  POWER FORWARD   31
#
#                         team  games_played  minutes_played  \
# 5        VANCOUVER GRIZZLIES            81            3241
# 465            ATLANTA HAWKS            77            2980
# 898            ATLANTA HAWKS            81            3087
# 1359                    None            85            2684
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM per_100_stats'
per_100_stats_df = pd.read_sql_query(query, conn)

conn.close()

per_100_stats_df.head()
# Out:
#    season_end_year  player_id     player_name nickname     team_id  \
# 0             2001        920      A.C. Green     A.C.  1610612748
# 1             2001       2062     A.J. Guyton     A.J.  1610612741
# 2             2001        243     Aaron McKie    Aaron  1610612755
# 3             2001       1425  Aaron Williams    Aaron  1610612751
# 4             2001        228      Adam Keefe     Adam  1610612744
#
#   team_abbreviation   age  gp   w   l  w_pct  per_100_min  per_100_fgm  \
# 0               MIA  37.0  82  50  32  0.610         53.1          5.4
# 1               CHI  23.0  33   6  27  0.182         53.6          6.6
# 2               PHI  28.0  76  51  25  0.671         51.5          7.3
# 3               NJN  29.0  82  26  56  0.317         51.6          6.6
# 4               GSW  31.0  67  14  53  0.209         50.5          3.8
#
#    per_100_fga  per_100_fg_pct  per_100_fg3m  per_100_fg3a  per_100_fg3_pct  \
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM league_averages'
league_averages_df = pd.read_sql_query(query, conn)

conn.close()

league_averages_df
# Out:
#    season_label  average_age average_height  average_weight  \
# 0       2000-01         27.7            6-7             217
# 1       2001-02         27.4            6-7             218
# 2       2002-03         27.2            6-7             219
# 3       2003-04         27.0            6-7             220
# 4       2004-05         26.9            6-7             220
# 5       2005-06         26.5            6-7             220
# 6       2006-07         26.6            6-7             219
# 7       2007-08         26.8            6-7             220
# 8       2008-09         26.6            6-7             221
# 9       2009-10         26.6            6-7             222
# 10      2010-11         26.6            6-7             223
# 11      2011-12         26.6            6-7             223
# 12      2012-13         26.7            6-7             223
# 13      2013-14         26.5            6-7             223
# 14      2014-15         26.7            6-7             223
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM team_per_100_stats'

team_per_100_stats_df = pd.read_sql_query(query, conn)
conn.close()
team_per_100_stats_df
# Out:
#      season_end_year     team_id            team_name  gp   w   l  w_pct  \
# 0               2001  1610612737        Atlanta Hawks  82  25  57  0.305
# 1               2001  1610612738       Boston Celtics  82  36  46  0.439
# 2               2001  1610612766    Charlotte Hornets  82  46  36  0.561
# 3               2001  1610612741        Chicago Bulls  82  15  67  0.183
# 4               2001  1610612739  Cleveland Cavaliers  82  30  52  0.366
# ..               ...         ...                  ...  ..  ..  ..    ...
# 771             2026  1610612758     Sacramento Kings  82  22  60  0.268
# 772             2026  1610612759    San Antonio Spurs  82  62  20  0.756
# 773             2026  1610612761      Toronto Raptors  82  46  36  0.561
# 774             2026  1610612762            Utah Jazz  82  22  60  0.268
# 775             2026  1610612764   Washington Wizards  82  17  65  0.207
#
#      per_100_min  per_100_fgm  per_100_fga  per_100_fg_pct  per_100_fg3m  \
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM nba_per_100_averages'

league_per_100_stats_df = pd.read_sql_query(query, conn)
conn.close()
league_per_100_stats_df
# Out:
#     season_end_year  per_100_fgm  per_100_fga  per_100_fg_pct  per_100_fg3m  \
# 0              2001    38.224138    86.313793        0.442862      5.189655
# 1              2002    39.062069    87.779310        0.445069      5.613793
# 2              2003    38.365517    86.810345        0.442034      5.506897
# 3              2004    38.017241    86.658621        0.438483      5.624138
# 4              2005    38.650000    86.400000        0.447433      6.023333
# 5              2006    38.736667    85.393333        0.453733      6.176667
# 6              2007    38.946667    85.006667        0.458333      6.450000
# 7              2008    39.613333    86.673333        0.457167      6.953333
# 8              2009    39.740000    86.633333        0.458867      7.113333
# 9              2010    39.993333    86.703333        0.461467      6.813333
# 10             2011    39.783333    86.743333        0.458733      6.883333
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM nba_advanced_averages'

team_advanced_averages_df = pd.read_sql_query(query, conn)
conn.close()
team_advanced_averages_df
# Out:
#     season_end_year          min  e_off_rating  off_rating  e_def_rating  \
# 0              2001  3969.103448    100.234483  101.555172    100.220690
# 1              2002  3963.241379    101.575862  103.093103    101.603448
# 2              2003  3968.344828    100.706897  102.162069    100.703448
# 3              2004  3963.931034    100.031034  101.393103    100.017241
# 4              2005  3966.666667    103.063333  104.506667    103.073333
# 5              2006  3970.333333    103.410000  104.856667    103.406667
# 6              2007  3971.666667    103.720000  105.276667    103.706667
# 7              2008  3960.666667    104.730000  106.196667    104.720000
# 8              2009  3964.333333    105.446667  106.983333    105.396667
# 9              2010  3963.333333    104.900000  106.583333    104.863333
# 10             2011  3967.000000    104.486667  106.313333    104.440000
# 11             2012  3193.666667    101.830000  103.496667    101.836667
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM scoring_plus WHERE slug = "thompkl01"'

klay_plus_df = pd.read_sql_query(query, conn)
conn.close()
klay_plus_df
# Out:
#     season_end_year       slug           name  per_100_pts  \
# 0              2012  thompkl01  Klay Thompson         26.1
# 1              2013  thompkl01  Klay Thompson         23.1
# 2              2014  thompkl01  Klay Thompson         25.5
# 3              2015  thompkl01  Klay Thompson         32.5
# 4              2016  thompkl01  Klay Thompson         31.4
# 5              2017  thompkl01  Klay Thompson         31.2
# 6              2018  thompkl01  Klay Thompson         27.6
# 7              2019  thompkl01  Klay Thompson         29.7
# 8              2022  thompkl01  Klay Thompson         32.8
# 9              2023  thompkl01  Klay Thompson         30.5
# 10             2024  thompkl01  Klay Thompson         28.3
# 11             2025  thompkl01  Klay Thompson         24.4
# 12             2026  thompkl01  Klay Thompson         24.4
#
#     true_shooting_percentage  league_avg_per_100_pts_per_player  \
# 0                      0.545                          20.699333
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = '''
SELECT name, scoring_plus, per_100_pts, true_shooting_percentage, pts_plus, ts_plus
FROM scoring_plus 
WHERE season_end_year = 2026
ORDER BY scoring_plus DESC
'''
scoring_plus_2026_df = pd.read_sql_query(query, conn)
conn.close()
scoring_plus_2026_df.head(25)
# Out:
#                        name  scoring_plus  per_100_pts  \
# 0           Harrison Ingram    140.497178         19.3
# 1             Norchad Omier    133.687515         34.0
# 2     Giannis Antetokounmpo    133.623541         45.9
# 3   Shai Gilgeous-Alexander    132.702679         44.1
# 4        Alex Antetokounmpo    127.993119         41.3
# 5                Mark Sears    127.920886         39.3
# 6            Walker Kessler    126.933566         22.9
# 7               Luka Dončić    126.762691         44.6
# 8             Caleb Houstan    126.742460         24.9
# 9               Zyon Pullin    126.626062         23.5
# 10            Kawhi Leonard    126.529483         42.7
# 11             Nikola Jokić    126.195560         37.1
# 12           Tristen Newton    125.634627         48.0
# 13          Trentyn Flowers    125.084005         36.4
# 14            Stephen Curry    124.511925         39.7
# 15                Ty Jerome    124.305960         42.2
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = '''
SELECT s.name, s.season_end_year, s.slug, s.scoring_plus, s.per_100_pts, s.true_shooting_percentage, s.pts_plus, s.ts_plus
FROM scoring_plus as s
JOIN basic_stats as b ON s.slug = b.slug AND s.season_end_year = b.season_end_year
WHERE b.minutes_played > 1500
ORDER BY scoring_plus DESC
'''
scoring_plus_leaders_df = pd.read_sql_query(query, conn)
conn.close()
scoring_plus_leaders_df.head(25)
# Out:
#                        name  season_end_year       slug  scoring_plus  \
# 0             Stephen Curry             2016  curryst01    140.348678
# 1              James Harden             2019  hardeja01    135.767754
# 2              Kevin Durant             2014  duranke01    135.265163
# 3               Joel Embiid             2023  embiijo01    134.756972
# 4              Kevin Durant             2013  duranke01    134.238894
# 5             Stephen Curry             2018  curryst01    133.950260
# 6         Amar'e Stoudemire             2008  stoudam01    133.318311
# 7              LeBron James             2014  jamesle01    133.019945
# 8   Shai Gilgeous-Alexander             2026  gilgesh01    132.702679
# 9              LeBron James             2013  jamesle01    132.677153
# 10            Stephen Curry             2021  curryst01    132.407172
# 11            Isaiah Thomas             2017  thomais02    131.919187
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM player_profile WHERE qualified = 1'
player_profile_df = pd.read_sql_query(query, conn)
conn.close()

player_profile_df
# Out:
#              player_name             team_name team_abbreviation     team_id  \
# 0            Aaron McKie    PHILADELPHIA 76ERS               PHI  1610612755
# 1         Aaron Williams       NEW JERSEY NETS               NJN  1610612751
# 2          Al Harrington        INDIANA PACERS               IND  1610612754
# 3         Alan Henderson         ATLANTA HAWKS               ATL  1610612737
# 4          Allan Houston       NEW YORK KNICKS               NYK  1610612752
# ...                  ...                   ...               ...         ...
# 4860   Victor Wembanyama     SAN ANTONIO SPURS               SAS  1610612759
# 4861  Wendell Carter Jr.         ORLANDO MAGIC               ORL  1610612753
# 4862          Will Riley    WASHINGTON WIZARDS               WAS  1610612764
# 4863  Zaccharie Risacher         ATLANTA HAWKS               ATL  1610612737
# 4864     Zion Williamson  NEW ORLEANS PELICANS               NOP  1610612740
#
# ...

# %%
plus_leaders_2026 = player_profile_df[player_profile_df['season_end_year'] == 2026].sort_values(by='scoring_plus', ascending=False).head(25)
plus_leaders_2026
# Out:
#                   player_name                                 team_name  \
# 4847  Shai Gilgeous-Alexander                     OKLAHOMA CITY THUNDER
# 4802              Luka Dončić                        LOS ANGELES LAKERS
# 4788            Kawhi Leonard                      LOS ANGELES CLIPPERS
# 4819             Nikola Jokić                            DENVER NUGGETS
# 4765              Jalen Duren                           DETROIT PISTONS
# 4860        Victor Wembanyama                         SAN ANTONIO SPURS
# 4708          Anthony Edwards                    MINNESOTA TIMBERWOLVES
# 4747         Donovan Mitchell                       CLEVELAND CAVALIERS
# 4792             Kevin Durant                           HOUSTON ROCKETS
# 4864          Zion Williamson                      NEW ORLEANS PELICANS
# 4774             Jaylen Brown                            BOSTON CELTICS
# 4710            Austin Reaves                        LOS ANGELES LAKERS
# ...

# %%
ppg_leaders_2026 = player_profile_df[player_profile_df['season_end_year'] == 2026].sort_values(by='points_per_game', ascending=False).head(25)
ppg_leaders_2026
# Out:
#                   player_name                                 team_name  \
# 4802              Luka Dončić                        LOS ANGELES LAKERS
# 4847  Shai Gilgeous-Alexander                     OKLAHOMA CITY THUNDER
# 4708          Anthony Edwards                    MINNESOTA TIMBERWOLVES
# 4774             Jaylen Brown                            BOSTON CELTICS
# 4858             Tyrese Maxey                        PHILADELPHIA 76ERS
# 4788            Kawhi Leonard                      LOS ANGELES CLIPPERS
# 4747         Donovan Mitchell                       CLEVELAND CAVALIERS
# 4819             Nikola Jokić                            DENVER NUGGETS
# 4742             Devin Booker                              PHOENIX SUNS
# 4764            Jalen Brunson                           NEW YORK KNICKS
# 4792             Kevin Durant                           HOUSTON ROCKETS
# 4768             Jamal Murray                            DENVER NUGGETS
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM scoring_splits'
scoring_splits_df = pd.read_sql_query(query, conn)

conn.close()

scoring_splits_df
# Out:
#        season_end_year  player_id      player_name nickname     team_id  \
# 0                 2001        920       A.C. Green     A.C.  1610612748
# 1                 2001       2062      A.J. Guyton     A.J.  1610612741
# 2                 2001        243      Aaron McKie    Aaron  1610612755
# 3                 2001       1425   Aaron Williams    Aaron  1610612751
# 4                 2001        228       Adam Keefe     Adam  1610612744
# ...                ...        ...              ...      ...         ...
# 12805             2026     203897      Zach LaVine     Zach  1610612758
# 12806             2026    1630192       Zeke Nnaji     Zeke  1610612743
# 12807             2026    1630533  Ziaire Williams   Ziaire  1610612751
# 12808             2026    1629627  Zion Williamson     Zion  1610612740
# 12809             2026    1642389      Zyon Pullin     Zyon  1610612750
#
#       team_abbreviation   age  gp   w   l  w_pct   min  pct_fga_2pt  \
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM scoring_profile'
scoring_profile_df = pd.read_sql_query(query, conn)
conn.close()

scoring_profile_df
# Out:
#        season_end_year       slug  player_id      player_name     team_id  \
# 0                 2001  greenac01        920       A.C. Green  1610612748
# 1                 2001  guytoaj01       2062      A.J. Guyton  1610612741
# 2                 2001  mckieaa01        243      Aaron McKie  1610612755
# 3                 2001  williaa01       1425   Aaron Williams  1610612751
# 4                 2001  keefead01        228       Adam Keefe  1610612744
# ...                ...        ...        ...              ...         ...
# 12797             2026  lavinza01     203897      Zach LaVine  1610612758
# 12798             2026  nnajize01    1630192       Zeke Nnaji  1610612743
# 12799             2026  willizi02    1630533  Ziaire Williams  1610612751
# 12800             2026  willizi01    1629627  Zion Williamson  1610612740
# 12801             2026  pullizy01    1642389      Zyon Pullin  1610612750
#
#       team_abbreviation               team_name   age  gp  team_gp  \
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM player_profile'
player_profile_df = pd.read_sql_query(query, conn)
conn.close()

player_profile_df
# Out:
#            player_name               team_name team_abbreviation     team_id  \
# 0           A.C. Green              MIAMI HEAT               MIA  1610612748
# 1          A.J. Guyton           CHICAGO BULLS               CHI  1610612741
# 2          Aaron McKie      PHILADELPHIA 76ERS               PHI  1610612755
# 3       Aaron Williams         NEW JERSEY NETS               NJN  1610612751
# 4           Adam Keefe   GOLDEN STATE WARRIORS               GSW  1610612744
# ...                ...                     ...               ...         ...
# 12797      Zach LaVine        SACRAMENTO KINGS               SAC  1610612758
# 12798       Zeke Nnaji          DENVER NUGGETS               DEN  1610612743
# 12799  Ziaire Williams           BROOKLYN NETS               BKN  1610612751
# 12800  Zion Williamson    NEW ORLEANS PELICANS               NOP  1610612740
# 12801      Zyon Pullin  MINNESOTA TIMBERWOLVES               MIN  1610612750
#
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM team_advanced_stats'
team_advanced_stats_df = pd.read_sql_query(query, conn)
conn.close()

team_advanced_stats_df
# Out:
#      season_end_year     team_id            team_name  gp   w   l  w_pct  \
# 0               2001  1610612737        Atlanta Hawks  82  25  57  0.305
# 1               2001  1610612738       Boston Celtics  82  36  46  0.439
# 2               2001  1610612766    Charlotte Hornets  82  46  36  0.561
# 3               2001  1610612741        Chicago Bulls  82  15  67  0.183
# 4               2001  1610612739  Cleveland Cavaliers  82  30  52  0.366
# ..               ...         ...                  ...  ..  ..  ..    ...
# 771             2026  1610612758     Sacramento Kings  82  22  60  0.268
# 772             2026  1610612759    San Antonio Spurs  82  62  20  0.756
# 773             2026  1610612761      Toronto Raptors  82  46  36  0.561
# 774             2026  1610612762            Utah Jazz  82  22  60  0.268
# 775             2026  1610612764   Washington Wizards  82  17  65  0.207
#
#         min  e_off_rating  off_rating  e_def_rating  def_rating  e_net_rating  \
# ...

# %%
conn = sqlite3.connect('nba_stats.db')

query = 'SELECT * FROM team_per_game_stats'
team_per_game_stats_df = pd.read_sql_query(query, conn)
conn.close()

team_per_game_stats_df
# Out:
#      season_end_year     team_id            team_name  gp   w   l  w_pct  \
# 0               2001  1610612737        Atlanta Hawks  82  25  57  0.305
# 1               2001  1610612738       Boston Celtics  82  36  46  0.439
# 2               2001  1610612766    Charlotte Hornets  82  46  36  0.561
# 3               2001  1610612741        Chicago Bulls  82  15  67  0.183
# 4               2001  1610612739  Cleveland Cavaliers  82  30  52  0.366
# ..               ...         ...                  ...  ..  ..  ..    ...
# 771             2026  1610612758     Sacramento Kings  82  22  60  0.268
# 772             2026  1610612759    San Antonio Spurs  82  62  20  0.756
# 773             2026  1610612761      Toronto Raptors  82  46  36  0.561
# 774             2026  1610612762            Utah Jazz  82  22  60  0.268
# 775             2026  1610612764   Washington Wizards  82  17  65  0.207
#
#      per_game_min  per_game_fgm  per_game_fga  per_game_fg_pct  per_game_fg3m  \
# ...
